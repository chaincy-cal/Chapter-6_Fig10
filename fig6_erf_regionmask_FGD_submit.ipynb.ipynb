# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import geopandas as gp
import seaborn as sns
import pandas as pd
import cartopy.crs as ccrs
import numpy as np
import regionmask
from netCDF4 import Dataset
print(gp.__version__)  
from scipy import stats
# Out:
# 0.10.2

# %%
# read the erf netcdf file
erfdir='/home/chaincy/Downloads/ipcc/recipe_ck_erf_histSST-piNTCF_20210218_223207/plots/diffexpts/ar6fig6_erf'
erfdir='/home/chaincy/Downloads/ipcc/recipe_ck_erf_histSST-piNTCF_20210303_043919/plots/diffexpts/ar6fig6_erf'
erfdir='/home/chaincy/Downloads/ipcc/recipe_ck_erf_histSST-piAer_20210308_195740/plots/diffexpts/ar6fig6_erf'
ferf=Dataset('%s/erf_hatch_LW.nc' % erfdir,mode='r')
nlat=ferf.dimensions['lat'].size
nlon=ferf.dimensions['lon'].size
ntime=ferf.dimensions['time'].size

lat=np.zeros((nlat,))
lon=np.zeros((nlon,))
erflw=np.zeros((ntime,nlat,nlon))
hatchlw=np.zeros((ntime,nlat,nlon))

lat=ferf.variables['lat'][:]
lon=ferf.variables['lon'][:]
erflw[0,:,:] = ferf.variables['erf_mn'][:]
hatchlwnow = ferf.variables['significant'][:]

for ilat in range(0,nlat):
    for ilon in range(0,nlon):
        if(hatchlwnow[0,ilat,ilon]==0.0): # significant values are 0.0 in the mask
            hatchlw[0,ilat,ilon]= 1.0

# %%
# regiondir='/anaconda2/envs/geo_env/lib/python3.8/site-packages/regionmask/defined_regions/data/AR6_WGI_referenceRegions'
# df = gp.read_file("%s/AR6_WGI_referenceRegions.shp" % regiondir)

regiondir = '/home/chaincy/Downloads/ipcc/IPCC-WGI-reference-regions-v4'
df = gp.read_file("%s/IPCC-WGI-reference-regions-v4.shp" % regiondir)
df["i"] = df.index # assing the index as column, so we can use it to color the regions

# %%
df
# Out:
#           Continent        Type                       Name Acronym  \
# 0             POLAR        Land          Greenland/Iceland     GIC
# 1     NORTH-AMERICA        Land          N.W.North-America     NWN
# 2     NORTH-AMERICA        Land          N.E.North-America     NEN
# 3     NORTH-AMERICA        Land            W.North-America     WNA
# 4     NORTH-AMERICA        Land            C.North-America     CNA
# 5     NORTH-AMERICA        Land            E.North-America     ENA
# 6   CENTRAL-AMERICA        Land          N.Central-America     NCA
# 7   CENTRAL-AMERICA        Land          S.Central-America     SCA
# 8   CENTRAL-AMERICA  Land-Ocean                  Caribbean     CAR
# 9     SOUTH-AMERICA        Land          N.W.South-America     NWS
# 10    SOUTH-AMERICA        Land            N.South-America     NSA
# 11    SOUTH-AMERICA        Land          N.E.South-America     NES
# 12    SOUTH-AMERICA        Land     South-American-Monsoon     SAM
# 13    SOUTH-AMERICA        Land          S.W.South-America     SWS
# 14    SOUTH-AMERICA        Land          S.E.South-America     SES
# 15    SOUTH-AMERICA        Land            S.South-America     SSA
# 16           EUROPE        Land                   N.Europe     NEU
# 17           EUROPE        Land        West&Central-Europe     WCE
# 18           EUROPE        Land                   E.Europe     EEU
# 19    EUROPE-AFRICA  Land-Ocean              Mediterranean     MED
# 20           AFRICA        Land                     Sahara     SAH
# 21           AFRICA        Land             Western-Africa     WAF
# 22           AFRICA        Land             Central-Africa     CAF
# 23           AFRICA        Land           N.Eastern-Africa    NEAF
# 24           AFRICA        Land           S.Eastern-Africa    SEAF
# 25           AFRICA        Land          W.Southern-Africa    WSAF
# 26           AFRICA        Land          E.Southern-Africa    ESAF
# 27           AFRICA        Land                 Madagascar     MDG
# 28             ASIA        Land             Russian-Arctic     RAR
# 29             ASIA        Land                  W.Siberia     WSB
# 30             ASIA        Land                  E.Siberia     ESB
# 31             ASIA        Land           Russian-Far-East     RFE
# 32             ASIA        Land                   W.C.Asia     WCA
# 33             ASIA        Land                   E.C.Asia     ECA
# 34             ASIA        Land            Tibetan-Plateau     TIB
# 35             ASIA        Land                     E.Asia     EAS
# 36             ASIA        Land          Arabian-Peninsula     ARP
# 37             ASIA        Land                     S.Asia     SAS
# 38             ASIA  Land-Ocean                   S.E.Asia     SEA
# 39          OCEANIA        Land                N.Australia     NAU
# 40          OCEANIA        Land                C.Australia     CAU
# 41          OCEANIA        Land                E.Australia     EAU
# 42          OCEANIA        Land                S.Australia     SAU
# 43          OCEANIA        Land                New-Zealand      NZ
# 44            POLAR        Land               E.Antarctica     EAN
# 45            POLAR        Land               W.Antarctica     WAN
# 46           ARCTIC       Ocean               Arctic-Ocean     ARO
# 47          PACIFIC       Ocean            N.Pacific-Ocean     NPO
# 48          PACIFIC       Ocean   Equatorial.Pacific-Ocean     EPO
# 49          PACIFIC       Ocean            S.Pacific-Ocean     SPO
# 50         ATLANTIC       Ocean           N.Atlantic-Ocean     NAO
# 51         ATLANTIC       Ocean  Equatorial.Atlantic-Ocean     EAO
# 52         ATLANTIC       Ocean           S.Atlantic-Ocean     SAO
# 53           INDIAN       Ocean                Arabian-Sea     ARS
# 54           INDIAN       Ocean              Bay-of-Bengal     BOB
# 55           INDIAN       Ocean     Equatorial.Indic-Ocean     EIO
# 56           INDIAN       Ocean              S.Indic-Ocean     SIO
# 57         SOUTHERN       Ocean             Southern-Ocean     SOO
#
#                                              geometry   i
# 0   POLYGON ((-10.00000 62.00000, -10.43750 62.000...   0
# 1   POLYGON ((-105.00000 50.00000, -105.43860 50.0...   1
# 2   POLYGON ((-50.00000 50.00000, -50.44000 50.000...   2
# 3   POLYGON ((-130.00000 50.00000, -129.56140 50.0...   3
# 4   POLYGON ((-90.00000 50.00000, -90.00000 49.561...   4
# 5   POLYGON ((-70.00000 25.00000, -70.43478 25.000...   5
# 6   POLYGON ((-90.00000 25.00000, -90.37179 24.769...   6
# 7   POLYGON ((-75.00000 12.00000, -75.28000 11.673...   7
# 8   POLYGON ((-75.00000 12.00000, -75.32609 12.282...   8
# 9   POLYGON ((-75.00000 12.00000, -74.57143 12.000...   9
# 10  POLYGON ((-72.00000 12.00000, -71.56410 12.000...  10
# 11  POLYGON ((-34.00000 -20.00000, -34.43243 -20.0...  11
# 12  POLYGON ((-66.40000 -20.00000, -66.71111 -19.7...  12
# 13  POLYGON ((-72.00000 -15.00000, -71.68889 -15.2...  13
# 14  POLYGON ((-34.00000 -20.00000, -34.32353 -20.2...  14
# 15  POLYGON ((-79.00000 -56.00000, -79.00000 -55.5...  15
# 16  POLYGON ((-10.00000 48.00000, -10.00000 48.439...  16
# 17  POLYGON ((-10.00000 45.00000, -10.00000 45.428...  17
# 18  POLYGON ((40.00000 45.00000, 40.00000 45.43478...  18
# 19  POLYGON ((-10.00000 30.00000, -10.00000 30.428...  19
# 20  POLYGON ((-20.00000 14.70000, -20.00000 15.137...  20
# 21  POLYGON ((-20.00000 7.60000, -20.00000 8.01765...  21
# 22  POLYGON ((8.00000 -10.00000, 8.00000 -9.56522,...  22
# 23  POLYGON ((27.00000 2.30000, 27.00000 2.72759, ...  23
# 24  POLYGON ((27.00000 -10.00000, 27.00000 -9.5607...  24
# 25  POLYGON ((8.00000 -36.00000, 8.00000 -35.56667...  25
# 26  POLYGON ((25.00000 -10.00000, 25.43878 -10.000...  26
# 27  POLYGON ((36.20000 -27.00000, 36.42391 -26.630...  27
# 28  MULTIPOLYGON (((40.00000 65.00000, 40.00000 65...  28
# 29  POLYGON ((60.00000 45.00000, 60.00000 45.43478...  29
# 30  POLYGON ((90.00000 45.00000, 90.00000 45.43478...  30
# 31  POLYGON ((130.00000 45.00000, 130.00000 45.434...  31
# 32  POLYGON ((40.00000 30.00000, 40.00000 30.42857...  32
# 33  POLYGON ((75.00000 37.00000, 75.00000 37.42105...  33
# 34  POLYGON ((75.00000 30.00000, 75.00000 30.43750...  34
# 35  POLYGON ((100.00000 19.50000, 100.00000 19.937...  35
# 36  POLYGON ((33.00000 30.00000, 33.42941 30.00000...  36
# 37  POLYGON ((60.00000 23.50000, 60.00000 23.93333...  37
# 38  POLYGON ((93.00000 -10.00000, 93.00000 -9.5661...  38
# 39  POLYGON ((110.00000 -20.00000, 110.00000 -19.5...  39
# 40  POLYGON ((110.00000 -30.00000, 110.00000 -29.5...  40
# 41  POLYGON ((145.50000 -32.90000, 145.50000 -32.4...  41
# 42  POLYGON ((110.00000 -36.00000, 110.00000 -35.5...  42
# 43  POLYGON ((155.00000 -50.00000, 155.00000 -49.5...  43
# 44  POLYGON ((-180.00000 -90.00000, -180.00000 -89...  44
# 45  POLYGON ((-180.00000 -83.00000, -180.00000 -82...  45
# 46  POLYGON ((-180.00000 90.00000, -179.56044 90.0...  46
# 47  MULTIPOLYGON (((132.00000 7.60000, 132.00000 8...  47
# 48  MULTIPOLYGON (((155.00000 -10.00000, 154.63492...  48
# 49  MULTIPOLYGON (((180.00000 -10.00000, 180.00000...  49
# 50  POLYGON ((-50.00000 7.60000, -50.32927 7.88537...  50
# 51  POLYGON ((-34.00000 -10.00000, -34.00000 -9.56...  51
# 52  POLYGON ((-56.00000 -56.00000, -56.00000 -55.5...  52
# 53  POLYGON ((53.00000 7.00000, 53.00000 7.42105, ...  53
# 54  POLYGON ((79.00000 7.00000, 79.23529 7.36765, ...  54
# 55  POLYGON ((46.50000 -10.00000, 46.50000 -9.5607...  55
# 56  POLYGON ((36.20000 -27.00000, 36.63077 -27.000...  56
# 57  POLYGON ((-180.00000 -56.00000, -179.56028 -56...  57

# %%
rgnnames=['ARCTIC','NORTH-AMERICA','CENTRAL-AMERICA','SOUTH-AMERICA','EUROPE','EUROPE-AFRICA',
          'AFRICA','ASIA','OCEANIA','ANTARCTICA','PACIFIC','ATLANTIC','INDIAN','SOUTHERN-OCEANS']
nlargergns=len(rgnnames)

erfswhatchpd=pd.DataFrame()
erflwhatchpd=pd.DataFrame()
erftothatchpd=pd.DataFrame()

for irgn in range(0,nlargergns):
    erflwhatchpd.loc[irgn,'Region']=rgnnames[irgn]
    erfswhatchpd.loc[irgn,'Region']=rgnnames[irgn]
    erftothatchpd.loc[irgn,'Region']=rgnnames[irgn]

# %%
# # define a longitude latitude grid
# lon = np.arange(-179.5, 180)
# lat = np.arange(-89.5, 90)

# # for the plotting
# lon_edges = np.arange(-180, 181)
# lat_edges = np.arange(-90, 91)

# %%
# dependence on the latitude and longitude grid
# take care that the regions are defined on the same lat and lon grid as the data.

# care must be taken in identifying input parameters for regionmask.Regions(). 
# The geometries and names/abbreviations must have unique ID's.  For example, if df.V1 is chosen, 
# the geometries are no longer unique and the associated geometry may not be correct.
#ar6wg1regions = regionmask.Regions(df.geometry, names=df.V2, abbrevs=df.V1, name='ar6wg1')
ar6wg1regions = regionmask.Regions(df.geometry, names=df.Name, abbrevs=df.Continent, name='ar6wg1')
# Out:
# /home/chaincy/anaconda3/envs/ipcc_geoimg/lib/python3.8/site-packages/regionmask/core/regions.py:410: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for p in poly:

# %%
#ar6wg1mask = ar6wg1regions.mask(lon, lat, xarray=False)
ar6wg1mask = ar6wg1regions.mask(lon, lat)

# %%
# read the erf netcdf file
erfdir='/home/chaincy/Downloads/ipcc/recipe_ck_erf_histSST-piAer_20210308_195740/plots/diffexpts/ar6fig6_erf'
ferf=Dataset('%s/erf_hatch_LW.nc' % erfdir,mode='r')
ferf=Dataset('%s/erf_hatch_SW.nc' % erfdir,mode='r')
nlat=ferf.dimensions['lat'].size
nlon=ferf.dimensions['lon'].size
ntime=ferf.dimensions['time'].size

lat=np.zeros((nlat,))
lon=np.zeros((nlon,))
erfsw=np.zeros((ntime,nlat,nlon))
hatchsw=np.zeros((ntime,nlat,nlon))

lat=ferf.variables['lat'][:]
lon=ferf.variables['lon'][:]
erfsw[0,:,:] = ferf.variables['erf_mn'][:]
hatchswnow = ferf.variables['significant'][:]

for ilat in range(0,nlat):
    for ilon in range(0,nlon):
        if(hatchswnow[0,ilat,ilon]==0.0): # significant values are 0.0 in the mask
            hatchsw[0,ilat,ilon]= 1.0

# %%
hatchswnow.shape
# Out:
# (1, 180, 360)

# %%
# determine the quandrangle area weight 

areaweight = np.zeros((nlat,nlon),dtype=float);
lat4wt = np.zeros((nlat,2),dtype=float);
lon4wt = np.zeros((nlon,2),dtype=float);
# assumption that cells are equally spaced., but this is not correct for latitudes
dellon = 360.0/nlon;
for ilat in range(0,nlat):
    if(ilat==0):
        dellat1 = (90.0-np.abs(lat[ilat]))/2;
    else:
        dellat1 = np.abs(lat[ilat]-lat[ilat-1])/2;
    if(ilat==nlat-1):
        dellat2 = (90.0-np.abs(lat[ilat]))/2;
    else:
        dellat2 = np.abs(lat[ilat+1]-lat[ilat])/2;

    lat4wt[ilat,0] = (lat[ilat]-dellat1)/180.0 * np.pi;
    lat4wt[ilat,1] = (lat[ilat]+dellat2)/180.0 * np.pi;
for ilon in range(0,nlon):
    lon4wt[ilon,0] = (lon[ilon]-dellon/2)/180.0 * np.pi;
    lon4wt[ilon,1] = (lon[ilon]+dellon/2)/180.0 * np.pi;
for ilat in range(0,nlat):
    for ilon in range(0,nlon):
        areaweight[ilat,ilon] = np.abs(lon4wt[ilon,1]-lon4wt[ilon,0]) * np.abs(np.sin(lat4wt[ilat,1])-np.sin(lat4wt[ilat,0])) / (4.0*np.pi);       
        
np.sum(areaweight)
# Out:
# 0.9999904807207345

# %%
erfrgnspd=df.copy()
erfrgnspd['LW_ERF']=0.0
erfrgnspd['SW_ERF']=0.0
erfrgnspd['TOT_ERF']=0.0

nrgns=len(ar6wg1regions.numbers)
    
eartharea = 4*np.pi*np.power(6378,2)    
totalarea = 0
    
erflw_mns=np.zeros((nrgns,))
erflw_hatch=np.zeros((nrgns,nlat,nlon))
erflw_hatch=np.ma.asarray(erflw_hatch)
rgn_hatchlw=np.zeros((nrgns,nlat,nlon))
rgn_hatchlw=np.ma.asarray(rgn_hatchlw)

erfsw_mns=np.zeros((nrgns,))
erfsw_hatch=np.zeros((nrgns,nlat,nlon))
erfsw_hatch=np.ma.asarray(erfsw_hatch)
rgn_hatchsw=np.zeros((nrgns,nlat,nlon))
rgn_hatchsw=np.ma.asarray(rgn_hatchsw)

ilarge=0
hatchindlw=nlargergns 
hatchindsw=nlargergns 
hatchindtot=nlargergns
for irgn in range(0,nrgns):
    #LW
    maskerflw = np.ma.masked_where(ar6wg1mask != irgn, erflw[0,:,:])
    rgn_hatchlw[irgn,:,:] = np.ma.masked_where(ar6wg1mask != irgn, hatchlw[0,:,:])
    
    wtmask = np.ma.masked_where(ar6wg1mask != irgn, areaweight)

    erflw_mns[irgn] = np.sum(maskerflw*wtmask)/np.sum(wtmask)
    erfrgnspd.loc[irgn,'LW_ERF'] = erflw_mns[irgn]
    
    erflw_hatch[irgn,:,:] = (maskerflw*rgn_hatchlw[irgn,:,:])
    erflw_hatch[irgn,:,:] = np.ma.masked_equal(erflw_hatch[irgn,:,:],0)
    
    #SW
    maskerfsw = np.ma.masked_where(ar6wg1mask != irgn, erfsw[0,:,:])
    rgn_hatchsw[irgn,:,:] = np.ma.masked_where(ar6wg1mask != irgn, hatchsw[0,:,:])

    erfsw_mns[irgn] = np.sum(maskerfsw*wtmask)/np.sum(wtmask)
    erfrgnspd.loc[irgn,'SW_ERF'] = erfsw_mns[irgn]
    
    erfsw_hatch[irgn,:,:] = (maskerfsw*rgn_hatchsw[irgn,:,:])
    erfsw_hatch[irgn,:,:] = np.ma.masked_equal(erfsw_hatch[irgn,:,:],0)
       
    erfrgnspd.loc[irgn,'TOT_ERF'] = erflw_mns[irgn] + erfsw_mns[irgn]
        
    for ilat in range(0,nlat):
        for ilon in range(0,nlon):
            if(erflw_hatch.mask[irgn,ilat,ilon]==False ):
                #erflwhatchpd.loc[hatchindlw,'Region']=df.loc[irgn,'V1'] # large region name
                erflwhatchpd.loc[hatchindlw,'Region']=df.loc[irgn,'Continent'] # large region name
                erflwhatchpd.loc[hatchindlw,'sigLWERF']=erflw_hatch.data[irgn,ilat,ilon]
                hatchindlw = hatchindlw + 1
            if(erfsw_hatch.mask[irgn,ilat,ilon]==False ):    
                erfswhatchpd.loc[hatchindsw,'Region']=df.loc[irgn,'Continent'] # large region name
                erfswhatchpd.loc[hatchindsw,'sigSWERF']=erfsw_hatch.data[irgn,ilat,ilon]
                hatchindsw = hatchindsw + 1
            if( (erflw_hatch.mask[irgn,ilat,ilon]==False) and (erfsw_hatch.mask[irgn,ilat,ilon]==False)):    
                erftothatchpd.loc[hatchindtot,'Region']=df.loc[irgn,'Continent'] # large region name
                erftothatchpd.loc[hatchindtot,'sigTOTERF']=erfsw_hatch.data[irgn,ilat,ilon]+erflw_hatch.data[irgn,ilat,ilon]
                hatchindtot = hatchindtot + 1

# %%
bAdditionalPlots=False

# %%
if(bAdditionalPlots):
    nrows=1
    ncols=2

    plt.rcParams['xtick.labelsize']=16
    plt.rcParams['ytick.labelsize']=16
    plt.rcParams["axes.labelsize"] = 24

    # colors
    nclr=['magenta','blueviolet','cornflowerblue','b','c','g','greenyellow','y','darkgoldenrod','orange','darksalmon','r','firebrick','saddlebrown']

    ax=plt.figure(figsize=(ncols*7,nrows*7))
    plt.subplots_adjust(wspace=0.3,hspace=0.90)

    alpha=0.4
    hatchbar='..'

    # lw barplot plus hatching, no errorbars    
    lwax=sns.barplot(y="Continent", x="LW_ERF", data=erfrgnspd, ci=None,  palette=nclr, label='Longwave ERF',edgecolor="0.2")
    for i,thisbar in enumerate(lwax.patches):
        thisbar.set_hatch(hatchbar)
        r, g, b, a = thisbar.get_facecolor()
        thisbar.set_facecolor((r, g, b, alpha))    
    # violin plots of the significant ERF grids
    lwvl=sns.violinplot(y='Region',x='sigLWERF',data=erflwhatchpd,inner=None,  palette=nclr)
    for i, violin in enumerate(lwvl.findobj(mpl.collections.PolyCollection)):
        violin.set_hatch(hatchbar)

    # sw barplot , no errorbars
    swax=sns.barplot(y="Continent", x="SW_ERF", data=erfrgnspd, ci=None, palette=nclr, label='Shortwave ERF',edgecolor="0.2")
    for i,thisbar in enumerate(swax.patches):
        r, g, b, a = thisbar.get_facecolor()
        thisbar.set_facecolor((r, g, b, alpha))
    swvl=sns.violinplot(y='Region',x='sigSWERF',data=erfswhatchpd,inner=None,  palette=nclr)

    # plot the zero line ERF
    yrng=[0,1]
    axes2 = plt.twinx()
    axes2.plot([0,0], yrng,color='k')#,label='Zero line')
    axes2.set_ylim(0,1)
    axes2.tick_params(labelright=False) 

    axes2.set_xlim(-12.5,4.5)

    plt.title('Mean Regional Effective Radiative Forcing''\n''due to Aerosols',fontsize=28)
    lwvl.set(xlabel=r'[W m$^{-2}$]',ylabel='')

    plt.figtext(0.0,0.96,'b)',fontsize=24)

    ax.legend( bbox_to_anchor=(0.375, 0.65), ncol=1, fontsize=14)

    # plt.savefig('fig6_erfSWLW_regionbar.png',dpi=300,bbox_inches='tight')

# %%
#from mpl_toolkits.axes_grid1.inset_locator import inset_axes

nrows=1
ncols=2

plt.rcParams['xtick.labelsize']=16
plt.rcParams['ytick.labelsize']=16
plt.rcParams["axes.labelsize"] = 24

# colors
nclr=['magenta','blueviolet','cornflowerblue','b','c','g','greenyellow','y','darkgoldenrod','orange','darksalmon','r','firebrick','saddlebrown']

#ax=plt.figure(figsize=(ncols*7,nrows*7))
fig,ax=plt.subplots(figsize=[ncols*7,nrows*7])
plt.subplots_adjust(wspace=0.3,hspace=0.90)

alpha=0.4
hatchbar='..'

# lw barplot plus hatching, no errorbars    
lwax=sns.barplot(y="Continent", x="LW_ERF", data=erfrgnspd, ci=None,  palette=nclr, label='Longwave ERF',edgecolor="0.2")
for i,thisbar in enumerate(lwax.patches):
    thisbar.set_hatch(hatchbar)
    r, g, b, a = thisbar.get_facecolor()
    thisbar.set_facecolor((r, g, b, alpha))    
# violin plots of the significant ERF grids
lwvl=sns.violinplot(y='Region',x='sigLWERF',data=erflwhatchpd,inner=None,  palette=nclr)
for i, violin in enumerate(lwvl.findobj(mpl.collections.PolyCollection)):
    violin.set_hatch(hatchbar)
    
# sw barplot , no errorbars
swax=sns.barplot(y="Continent", x="SW_ERF", data=erfrgnspd, ci=None, palette=nclr, label='Shortwave ERF',edgecolor="0.2")
for i,thisbar in enumerate(swax.patches):
    r, g, b, a = thisbar.get_facecolor()
    thisbar.set_facecolor((r, g, b, alpha))
swvl=sns.violinplot(y='Region',x='sigSWERF',data=erfswhatchpd,inner=None,  palette=nclr)

# plot the zero line ERF
yrng=[0,1]
axes2 = plt.twinx()
axes2.plot([0,0], yrng,color='k')#,label='Zero line')
axes2.set_ylim(0,1)
axes2.tick_params(labelright=False) 

axes2.set_xlim(-12.5,6.5)

plt.title('Mean Regional Effective Radiative Forcing''\n''due to Aerosols',fontsize=28)
lwvl.set(xlabel=r'[W m$^{-2}$]',ylabel='')

plt.figtext(0.0,0.96,'b)',fontsize=24)

ax.legend( bbox_to_anchor=(0.25, 0.95), ncol=1, fontsize=14)

#inset axis for violin legend
snormal=np.random.normal(1,0.1,10000)
axins = ax.inset_axes([0.05,0.6,0.02,0.2])
parts=axins.violinplot(snormal,showextrema=False)
for pc in parts['bodies']:
    pc.set_edgecolor('black')
    pc.set_facecolor(nclr[0])
    pc.set_alpha(1.0)
axins.tick_params( bottom=False, top=False,  right=False, left=False, labelbottom=False, labelleft=False)
axins.spines["top"].set_color("none")
axins.spines["bottom"].set_color("none")
axins.spines["right"].set_color("none")
axins.spines["left"].set_color("none")

xvlgd = -10.9
ax.text(xvlgd,4.1,'more frequent',fontsize=14)
ax.text(xvlgd,3.1,'less frequent',fontsize=14)
ax.hlines(xmin=xvlgd-0.7,xmax=xvlgd, y=3.9,linewidth=1, color='k')
ax.hlines(xmin=xvlgd-0.7,xmax=xvlgd, y=2.9, linewidth=1, color='k')

# plt.savefig('fig6_erfSWLW_regionbar.png',dpi=300,bbox_inches='tight')
# plt.savefig('fig6_erfSWLW_regionbar.svg',dpi=300,bbox_inches='tight')
plt.savefig('ar6_wg1_chap6_fig6_10b_SWLW_aer.png',dpi=300,bbox_inches='tight')
# Out:
# /tmp/ipykernel_69427/2212739947.py:21: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   lwax=sns.barplot(y="Continent", x="LW_ERF", data=erfrgnspd, ci=None,  palette=nclr, label='Longwave ERF',edgecolor="0.2")
# /tmp/ipykernel_69427/2212739947.py:32: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   swax=sns.barplot(y="Continent", x="SW_ERF", data=erfrgnspd, ci=None, palette=nclr, label='Shortwave ERF',edgecolor="0.2")

# %%
if(bAdditionalPlots):
    nrows=1
    ncols=2

    plt.rcParams['xtick.labelsize']=16
    plt.rcParams['ytick.labelsize']=16
    plt.rcParams["axes.labelsize"] = 24

    # colors
    nclr=['magenta','blueviolet','cornflowerblue','b','c','g','greenyellow','y','darkgoldenrod','orange','darksalmon','r','firebrick','saddlebrown']

    ax=plt.figure(figsize=(ncols*7,nrows*7))
    plt.subplots_adjust(wspace=0.3,hspace=0.90)

    alpha=0.5
    hatchbar='..'

    # lw barplot plus hatching, no errorbars    
    lwax=sns.barplot(y="Continent", x="TOT_ERF", data=erfrgnspd, ci=None,  palette=nclr, label='NET ERF',edgecolor="0.2")
    for i,thisbar in enumerate(lwax.patches):
        r, g, b, a = thisbar.get_facecolor()
        thisbar.set_facecolor((r, g, b, alpha))    
    # violin plots of the significant ERF grids
    lwvl=sns.violinplot(y='Region',x='sigTOTERF',data=erftothatchpd,inner=None,  palette=nclr)



    # plot the zero line ERF
    yrng=[0,1]
    axes2 = plt.twinx()
    axes2.plot([0,0], yrng,color='k',label='Zero line')
    axes2.set_ylim(0,1)
    axes2.tick_params(labelright=False) 
    axes2.set_xlim(-12.5,4.5)

    plt.title('Net Mean Effective Radiative Forcing by Region',fontsize=28)
    lwvl.set(xlabel=r'Effective Radiative Forcing [W m$^{-2}$]',ylabel='Region')

    ax.legend( bbox_to_anchor=(0.375, 0.85), ncol=1, fontsize=14)

    plt.savefig('fig6_erfNET_regionbar.png',dpi=300,bbox_inches='tight')

# %%
if(bAdditionalPlots):
    nrows=2
    ncols=1

    plt.rcParams['xtick.labelsize']=16
    plt.rcParams['ytick.labelsize']=16
    plt.rcParams["axes.labelsize"] = 24

    # colors
    nclr=['magenta','blueviolet','cornflowerblue','b','c','g','greenyellow','y','darkgoldenrod','orange','darksalmon','r','firebrick','saddlebrown']

    ax=plt.figure(figsize=(ncols*10,nrows*7))
    plt.subplots_adjust(wspace=0.3,hspace=0.4,top=0.9)
    plt.suptitle('Mean Effective Radiative Forcing by Region',fontsize=28)

    alpha=0.4
    hatchbarlw='..'
    hatchbarsw='//'

    plt.subplot(nrows,ncols,2)
    # lw barplot plus hatching, no errorbars    
    lwax=sns.barplot(y="Continent", x="LW_ERF", data=erfrgnspd, ci=None,  palette=nclr, label='Longwave ERF',edgecolor="0.2")
    for i,thisbar in enumerate(lwax.patches):
        thisbar.set_hatch(hatchbarlw)
        r, g, b, a = thisbar.get_facecolor()
        thisbar.set_facecolor((r, g, b, alpha))    
    # violin plots of the significant ERF grids
    lwvl=sns.violinplot(y='Region',x='sigLWERF',data=erflwhatchpd,inner=None,  palette=nclr)
    for i, violin in enumerate(lwvl.findobj(mpl.collections.PolyCollection)):
        violin.set_hatch(hatchbar)

    # sw barplot , no errorbars
    swax=sns.barplot(y="Continent", x="SW_ERF", data=erfrgnspd, ci=None, palette=nclr, label='Shortwave ERF',edgecolor="0.2")
    for i,thisbar in enumerate(swax.patches):

        r, g, b, a = thisbar.get_facecolor()
        thisbar.set_facecolor((r, g, b, alpha))
    swvl=sns.violinplot(y='Region',x='sigSWERF',data=erfswhatchpd,inner=None,  palette=nclr)

    # plot the zero line ERF
    yrng=[0,1]
    axes2 = plt.twinx()
    axes2.plot([0,0], yrng,color='k')
    axes2.set_ylim(0,1)
    axes2.tick_params(labelright=False) 

    axes2.set_xlim(-12.5,6)

    plt.title('Shortwave and Longwave ERF',fontsize=24)
    lwvl.set(xlabel=r'Effective Radiative Forcing [W m$^{-2}$]',ylabel='Region')

    plt.subplot(nrows,ncols,1)
    alpha=0.5
    hatchbar='..'

    # lw barplot plus hatching, no errorbars    
    netax=sns.barplot(y="Continent", x="TOT_ERF", data=erfrgnspd, ci=None,  palette=nclr, label='NET ERF',edgecolor="0.2")
    for i,thisbar in enumerate(netax.patches):
        thisbar.set_hatch(hatchbarsw)
        r, g, b, a = thisbar.get_facecolor()
        thisbar.set_facecolor((r, g, b, alpha))    
    # violin plots of the significant ERF grids
    lwvl=sns.violinplot(y='Region',x='sigTOTERF',data=erftothatchpd,inner=None,  palette=nclr)



    # plot the zero line ERF
    yrng=[0,1]
    axes2 = plt.twinx()
    axes2.plot([0,0], yrng,color='k',label='Zero line')
    axes2.set_ylim(0,1)
    axes2.tick_params(labelright=False) 
    axes2.set_xlim(-12.5,6)


    plt.title('Net ERF',fontsize=24)
    lwvl.set(xlabel=r'Effective Radiative Forcing [W m$^{-2}$]',ylabel='Region')

    ax.legend( bbox_to_anchor=(0.375, 0.9), ncol=1, fontsize=14)

    plt.figtext(-0.1,0.9,'a)',fontsize=24)
    plt.figtext(-0.1,0.45,'b)',fontsize=24)

    plt.savefig('fig6_erfALL_regionbar.png',dpi=300,bbox_inches='tight')
